# %% [markdown]
# # AI Healthcare Analytics Notebook
# Use this notebook to explore claims, denials, provider performance, and authorization trends.

# %%
import pandas as pd
df = pd.read_csv('../data/healthcare_claims_sample.csv')
df.head()
